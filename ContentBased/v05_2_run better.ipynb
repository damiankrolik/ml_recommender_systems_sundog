# %% [markdown]
# ### ContentKNNAlgorithm mod with year rating only
#
# commented oryginal part in Evaluators.py

# %%
# ~27.5 min run
# !python ./ContentRecs.py
# Out:
# Loading movie ratings...
#
# Computing movie popularity ranks so we can measure novelty later...
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating  ContentKNN ...
# Evaluating accuracy...
# Computing content-based similarity matrix...
# 0  of  8211
# 100  of  8211
# 200  of  8211
# 300  of  8211
# 400  of  8211
# 500  of  8211
# 600  of  8211
# 700  of  8211
# 800  of  8211
# 900  of  8211
# 1000  of  8211
# 1100  of  8211
# 1200  of  8211
# 1300  of  8211
# 1400  of  8211
# 1500  of  8211
# 1600  of  8211
# 1700  of  8211
# 1800  of  8211
# 1900  of  8211
# 2000  of  8211
# 2100  of  8211
# 2200  of  8211
# 2300  of  8211
# 2400  of  8211
# 2500  of  8211
# 2600  of  8211
# 2700  of  8211
# 2800  of  8211
# 2900  of  8211
# 3000  of  8211
# 3100  of  8211
# 3200  of  8211
# 3300  of  8211
# 3400  of  8211
# 3500  of  8211
# 3600  of  8211
# 3700  of  8211
# 3800  of  8211
# 3900  of  8211
# 4000  of  8211
# ...

# %% [markdown]
# above output:
# ```
# ...done.
# Computing recommendations...
#
# We recommend:
# Clerks (1994) 3.3711248007585746
# Quiz Show (1994) 3.3711248007585746
# Ed Wood (1994) 3.3711248007585746
# Legends of the Fall (1994) 3.3711248007585746
# Crow, The (1994) 3.3711248007585746
# Hoop Dreams (1994) 3.3711248007585746
# Muriel's Wedding (1994) 3.3711248007585746
# Disclosure (1994) 3.3711248007585746
# Adventures of Priscilla, Queen of the Desert, The (1994) 3.3711248007585746
# River Wild, The (1994) 3.3711248007585746
#
# Using recommender  Random
#
# Building recommendation model...
# Computing recommendations...
#
# We recommend:
# Toy Story (1995) 5
# Fargo (1996) 5
# Babe (1995) 5
# Ocean's Eleven (2001) 5
# Wizard of Oz, The (1939) 5
# Who Framed Roger Rabbit? (1988) 5
# Dead Man Walking (1995) 5
# Birdcage, The (1996) 5
# This Is Spinal Tap (1984) 5
# Annie Hall (1977) 5
# ```
